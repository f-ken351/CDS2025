# %% [markdown]
# ## データビリティコンソーシアム eラーニング講座：AIを体系的に学ぶ
# ## 知識情報学（第4回）識別(3) サポートベクトルマシン
# - MIT Lisence
#
# ## SVMによるBreast Cancerデータの識別とハイパーパラメータ自動最適化
# - Optunaで最適パラメータを探索
#  - https://optuna.org
#  - 大まかな使い方は上記のCoce Exampleを参照
#  - （注）Google colabにはデフォルトで入っていないため，別途インストールが必要

# %%
# optunaのインストール（コメントアウト#を外して実行）
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 5.6 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 14.6 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import scale
import optuna

# %% [markdown]
# ### Breast Cancerデータのロード

# %%
bc = load_breast_cancer()
X_std = scale(bc.data)
y = bc.target

# データセット詳細
print(bc.DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 569
#
# :Number of Attributes: 30 numeric, predictive attributes and the class
#
# :Attribute Information:
#     - radius (mean of distances from center to points on the perimeter)
#     - texture (standard deviation of gray-scale values)
#     - perimeter
#     - area
#     - smoothness (local variation in radius lengths)
#     - compactness (perimeter^2 / area - 1.0)
#     - concavity (severity of concave portions of the contour)
#     - concave points (number of concave portions of the contour)
#     - symmetry
#     - fractal dimension ("coastline approximation" - 1)
#
#     The mean, standard error, and "worst" or largest (mean of the three
#     worst/largest values) of these features were computed for each image,
#     resulting in 30 features.  For instance, field 0 is Mean Radius, field
#     10 is Radius SE, field 20 is Worst Radius.
#
#     - class:
#             - WDBC-Malignant
#             - WDBC-Benign
#
# :Summary Statistics:
#
# ===================================== ====== ======
#                                         Min    Max
# ===================================== ====== ======
# radius (mean):                        6.981  28.11
# texture (mean):                       9.71   39.28
# perimeter (mean):                     43.79  188.5
# area (mean):                          143.5  2501.0
# smoothness (mean):                    0.053  0.163
# compactness (mean):                   0.019  0.345
# concavity (mean):                     0.0    0.427
# concave points (mean):                0.0    0.201
# symmetry (mean):                      0.106  0.304
# fractal dimension (mean):             0.05   0.097
# radius (standard error):              0.112  2.873
# texture (standard error):             0.36   4.885
# perimeter (standard error):           0.757  21.98
# area (standard error):                6.802  542.2
# smoothness (standard error):          0.002  0.031
# compactness (standard error):         0.002  0.135
# concavity (standard error):           0.0    0.396
# concave points (standard error):      0.0    0.053
# symmetry (standard error):            0.008  0.079
# fractal dimension (standard error):   0.001  0.03
# radius (worst):                       7.93   36.04
# texture (worst):                      12.02  49.54
# perimeter (worst):                    50.41  251.2
# area (worst):                         185.2  4254.0
# smoothness (worst):                   0.071  0.223
# compactness (worst):                  0.027  1.058
# concavity (worst):                    0.0    1.252
# concave points (worst):               0.0    0.291
# symmetry (worst):                     0.156  0.664
# fractal dimension (worst):            0.055  0.208
# ===================================== ====== ======
#
# :Missing Attribute Values: None
#
# :Class Distribution: 212 - Malignant, 357 - Benign
#
# :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
# :Donor: Nick Street
#
# :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. dropdown:: References
#
#   - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#     for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#     Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#     San Jose, CA, 1993.
#   - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#     prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#     July-August 1995.
#   - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#     to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#     163-171.

# %% [markdown]
# ### 学習データとテストデータに分割

# %%
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ### Optunaでハイパーパラメータを最適化
# - Optunaの使い方は，下記Code Exampleのscikit-learnを参照
#     - https://optuna.org/#code_examples
# - Optuna サンプリング関数
#     - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.trial.Trial.html
# - SVCのパラメータリストは下記を参照
#     - http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC
#
# ### 【オンライン演習】 最適化する目的関数の定義
# - rbfカーネルを使用し，クロスバリデーションによるテストデータに対する平均Accuracyを返すように設計する

# %%
def objective(trial):
    # γパラメータを対数一様分布からサンプリング
    param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)

    # 上でサンプリングされたハイパーパラメータを使用してSVMのインスタンス(rbfカーネル)を生成
    svm = SVC(kernel='rbf', gamma=param_gamma)

    # cross_val_score()を使用して学習データに対してクロスバリデーション
    score = cross_val_score(svm, X_train, y_train, cv=10)
    return score.mean()

# %%
# optunaのインスタンスを生成し，最適化を実行
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)
# Out:
# [I 2024-10-28 07:17:26,608] A new study created in memory with name: no-name-fee07fa8-feb6-434b-bb4b-39fa62fcbb0f
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:26,868] Trial 0 finished with value: 0.9560869565217391 and parameters: {'param_gamma': 0.002971854704700809}. Best is trial 0 with value: 0.9560869565217391.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:27,297] Trial 1 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 1.7144195981317687}. Best is trial 0 with value: 0.9560869565217391.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:27,597] Trial 2 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 606.7976558548384}. Best is trial 0 with value: 0.9560869565217391.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:27,686] Trial 3 finished with value: 0.9627053140096619 and parameters: {'param_gamma': 0.01143124142320312}. Best is trial 3 with value: 0.9627053140096619.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:27,993] Trial 4 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 61.20616918109582}. Best is trial 3 with value: 0.9627053140096619.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:28,263] Trial 5 finished with value: 0.8702415458937198 and parameters: {'param_gamma': 0.4201936042936442}. Best is trial 3 with value: 0.9627053140096619.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:28,539] Trial 6 finished with value: 0.6746376811594204 and parameters: {'param_gamma': 0.6702037221091487}. Best is trial 3 with value: 0.9627053140096619.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:28,649] Trial 7 finished with value: 0.9516908212560388 and parameters: {'param_gamma': 0.0020269970031243077}. Best is trial 3 with value: 0.9627053140096619.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:28,752] Trial 8 finished with value: 0.9649275362318841 and parameters: {'param_gamma': 0.01677272279399884}. Best is trial 8 with value: 0.9649275362318841.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:29,073] Trial 9 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 30.700225906000338}. Best is trial 8 with value: 0.9649275362318841.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:29,187] Trial 10 finished with value: 0.9714975845410627 and parameters: {'param_gamma': 0.043960617528329644}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:29,311] Trial 11 finished with value: 0.9714975845410627 and parameters: {'param_gamma': 0.04158074095234265}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:29,473] Trial 12 finished with value: 0.9605797101449276 and parameters: {'param_gamma': 0.08828054606411445}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:29,614] Trial 13 finished with value: 0.9693236714975846 and parameters: {'param_gamma': 0.07054827393689383}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:29,937] Trial 14 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 4.244198427347503}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:30,102] Trial 15 finished with value: 0.964975845410628 and parameters: {'param_gamma': 0.0843216817127103}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:30,218] Trial 16 finished with value: 0.9605314009661836 and parameters: {'param_gamma': 0.012856449902912685}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:30,803] Trial 17 finished with value: 0.9407729468599035 and parameters: {'param_gamma': 0.1888021817670982}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:31,772] Trial 18 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 6.6648582638789575}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:32,140] Trial 19 finished with value: 0.9494685990338164 and parameters: {'param_gamma': 0.001078538158079162}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:32,561] Trial 20 finished with value: 0.9714975845410627 and parameters: {'param_gamma': 0.03046213893178582}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:32,943] Trial 21 finished with value: 0.9714975845410627 and parameters: {'param_gamma': 0.026829673337919108}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:33,172] Trial 22 finished with value: 0.962657004830918 and parameters: {'param_gamma': 0.006008184877200226}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:33,518] Trial 23 finished with value: 0.9693236714975846 and parameters: {'param_gamma': 0.05688727597802198}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:34,227] Trial 24 finished with value: 0.9297101449275363 and parameters: {'param_gamma': 0.3619096231143898}. Best is trial 10 with value: 0.9714975845410627.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:34,474] Trial 25 finished with value: 0.9736714975845411 and parameters: {'param_gamma': 0.025050789400535643}. Best is trial 25 with value: 0.9736714975845411.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:34,588] Trial 26 finished with value: 0.9604347826086957 and parameters: {'param_gamma': 0.006846100583698419}. Best is trial 25 with value: 0.9736714975845411.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:34,844] Trial 27 finished with value: 0.9429468599033817 and parameters: {'param_gamma': 0.18204378433325213}. Best is trial 25 with value: 0.9736714975845411.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:35,161] Trial 28 finished with value: 0.6263285024154589 and parameters: {'param_gamma': 1.7356409273630737}. Best is trial 25 with value: 0.9736714975845411.
# <ipython-input-5-00d86ca7e910>:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma = trial.suggest_loguniform('param_gamma', 1e-3, 1e3)
# [I 2024-10-28 07:17:35,267] Trial 29 finished with value: 0.9560869565217391 and parameters: {'param_gamma': 0.0037794370000210267}. Best is trial 25 with value: 0.9736714975845411.

# %% [markdown]
# ### 【提出課題】 Bestパラメータで再学習し，学習データおよびテストデータに対するAccuracyを算出

# %%
# optunaで最適化したBestパラメータで再学習．Bestパラメータは，study.best_params['パラメータ名']で参照可能
svm_best = SVC(kernel='rbf', gamma=study.best_params['param_gamma'])

svm_best.fit(X_train, y_train)
trn_acc = svm_best.score(X_train, y_train)
tst_acc = svm_best.score(X_test, y_test)

print('Training data: %1.3f' % trn_acc)
print('Test data: %1.3f' % tst_acc)
# Out:
# Training data: 0.987
# Test data: 0.965

# %% [markdown]
# ### Best パラメータを表示

# %%
print(study.best_params)
# Out:
# {'param_gamma': 0.025050789400535643}

# %% [markdown]
# ###【提出課題2（発展）】objective関数にrbfカーネル以外のカーネル関数も探索に追加し，カーネル関数も含めて最適化するように拡張しなさい．

# %%
def objective_new(trial):
    param_kernel = trial.suggest_categorical('param_kernel', ['rbf', 'poly'])
    if(param_kernel=='rbf'):
        param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
        svm = SVC(kernel='rbf', gamma=param_gamma_rbf)
    else:
        param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
        param_degree = trial.suggest_int('param_degree', 1, 4)
        param_coef0 =  trial.suggest_int('param_coef0', 0, 1e3)
        svm = SVC(kernel='poly', gamma=param_gamma_poly,
              degree=param_degree, coef0=param_coef0)

    score = cross_val_score(svm, X_train, y_train, cv=10)
    return score.mean()

# %%
study_new = optuna.create_study(direction='maximize')
study_new.optimize(objective_new, n_trials=100)
# Out:
# [I 2024-10-28 07:27:10,089] A new study created in memory with name: no-name-a8cfef2c-2292-40a7-9673-7b1cc2432938
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:10,379] Trial 0 finished with value: 0.8018840579710146 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.4943315354500663}. Best is trial 0 with value: 0.8018840579710146.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:10,697] Trial 1 finished with value: 0.9539613526570049 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002497759400162177, 'param_degree': 4, 'param_coef0': 113}. Best is trial 1 with value: 0.9539613526570049.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:10,790] Trial 2 finished with value: 0.9627053140096619 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.42404018490938683, 'param_degree': 4, 'param_coef0': 177}. Best is trial 2 with value: 0.9627053140096619.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:10,897] Trial 3 finished with value: 0.9538647342995169 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.0020808982281317785}. Best is trial 2 with value: 0.9627053140096619.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:10,985] Trial 4 finished with value: 0.9560386473429953 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 773.0455778648625, 'param_degree': 3, 'param_coef0': 225}. Best is trial 2 with value: 0.9627053140096619.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:11,134] Trial 5 finished with value: 0.9604830917874396 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.20382891788581747, 'param_degree': 2, 'param_coef0': 593}. Best is trial 2 with value: 0.9627053140096619.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:11,232] Trial 6 finished with value: 0.9604347826086956 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 1.2578159335840908, 'param_degree': 4, 'param_coef0': 906}. Best is trial 2 with value: 0.9627053140096619.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:11,329] Trial 7 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002440507285895614, 'param_degree': 2, 'param_coef0': 756}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:11,665] Trial 8 finished with value: 0.6263285024154589 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 51.41249281572399}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:11,753] Trial 9 finished with value: 0.9736231884057972 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002305526592089673, 'param_degree': 2, 'param_coef0': 118}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:11,992] Trial 10 finished with value: 0.6263285024154589 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 986.860211910606}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,078] Trial 11 finished with value: 0.9385024154589372 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010084249110536478, 'param_degree': 1, 'param_coef0': 679}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,213] Trial 12 finished with value: 0.9605797101449275 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.017837590275833724, 'param_degree': 2, 'param_coef0': 922}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,280] Trial 13 finished with value: 0.962657004830918 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.017861149512333866, 'param_degree': 1, 'param_coef0': 445}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,353] Trial 14 finished with value: 0.9583574879227053 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 21.406746203250623, 'param_degree': 2, 'param_coef0': 398}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,674] Trial 15 finished with value: 0.9538647342995169 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0066527689425290755, 'param_degree': 3, 'param_coef0': 725}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,752] Trial 16 finished with value: 0.9648309178743961 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.06462670690858836, 'param_degree': 2, 'param_coef0': 31}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,858] Trial 17 finished with value: 0.9692753623188406 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 9.700984487753393, 'param_degree': 1, 'param_coef0': 318}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:12,989] Trial 18 finished with value: 0.9472946859903383 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.0012259807490395704}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:13,225] Trial 19 finished with value: 0.956135265700483 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.032432511815714105, 'param_degree': 3, 'param_coef0': 799}. Best is trial 7 with value: 0.9758454106280194.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:13,335] Trial 20 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0012450350120062654, 'param_degree': 2, 'param_coef0': 548}. Best is trial 20 with value: 0.9780193236714976.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:13,445] Trial 21 finished with value: 0.9801932367149758 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.001539779480434535, 'param_degree': 2, 'param_coef0': 560}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:13,553] Trial 22 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0013191264315979617, 'param_degree': 2, 'param_coef0': 554}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:14,058] Trial 23 finished with value: 0.9539130434782608 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.006025008206398752, 'param_degree': 3, 'param_coef0': 555}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:14,189] Trial 24 finished with value: 0.9385024154589372 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010300331719715692, 'param_degree': 1, 'param_coef0': 605}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:14,322] Trial 25 finished with value: 0.9670531400966184 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.007710958091647887, 'param_degree': 2, 'param_coef0': 458}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:14,578] Trial 26 finished with value: 0.7996618357487923 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.48543721509283366}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:14,769] Trial 27 finished with value: 0.9583091787439614 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.14291962426340504, 'param_degree': 2, 'param_coef0': 321}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:14,891] Trial 28 finished with value: 0.9583091787439614 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 2.2032267923795827, 'param_degree': 3, 'param_coef0': 514}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:15,008] Trial 29 finished with value: 0.9714975845410627 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.030617106301787336}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:15,501] Trial 30 finished with value: 0.9451690821256038 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 556.3305090807994, 'param_degree': 1, 'param_coef0': 644}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:15,640] Trial 31 finished with value: 0.9692270531400966 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0033669131153886015, 'param_degree': 2, 'param_coef0': 778}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:15,779] Trial 32 finished with value: 0.9736714975845411 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0013341360916207224, 'param_degree': 2, 'param_coef0': 836}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:15,963] Trial 33 finished with value: 0.9649275362318841 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.010320254743601964, 'param_degree': 2, 'param_coef0': 698}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,072] Trial 34 finished with value: 0.9714975845410627 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0034907573399449504, 'param_degree': 2, 'param_coef0': 546}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,196] Trial 35 finished with value: 0.9627536231884057 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.03573687438485971, 'param_degree': 2, 'param_coef0': 379}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,443] Trial 36 finished with value: 0.9451690821256038 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010360877597510305, 'param_degree': 3, 'param_coef0': 491}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,524] Trial 37 finished with value: 0.9472946859903383 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002898497539790215, 'param_degree': 1, 'param_coef0': 748}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,745] Trial 38 finished with value: 0.6263285024154589 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 23.942294346244683}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,819] Trial 39 finished with value: 0.973719806763285 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002785761879060418, 'param_degree': 2, 'param_coef0': 612}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:16,938] Trial 40 finished with value: 0.956135265700483 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.013457259017167605, 'param_degree': 2, 'param_coef0': 853}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:17,024] Trial 41 finished with value: 0.9693236714975846 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002935802876415315, 'param_degree': 2, 'param_coef0': 624}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:17,098] Trial 42 finished with value: 0.9692753623188406 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0025570409078093173, 'param_degree': 2, 'param_coef0': 562}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:17,197] Trial 43 finished with value: 0.9670531400966184 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.006223719891457601, 'param_degree': 2, 'param_coef0': 664}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:17,476] Trial 44 finished with value: 0.9472946859903381 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.004182068224805023, 'param_degree': 3, 'param_coef0': 994}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:17,551] Trial 45 finished with value: 0.9801932367149758 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0013939559862001156, 'param_degree': 2, 'param_coef0': 602}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:17,767] Trial 46 finished with value: 0.6263285024154589 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 11.965038660450958}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:18,327] Trial 47 finished with value: 0.947391304347826 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0019182561324080694, 'param_degree': 4, 'param_coef0': 510}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:18,448] Trial 48 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010194471939586546, 'param_degree': 2, 'param_coef0': 426}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:18,573] Trial 49 finished with value: 0.9670531400966184 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.024465461605804713, 'param_degree': 1, 'param_coef0': 705}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:18,806] Trial 50 finished with value: 0.956135265700483 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.09522959546619739, 'param_degree': 2, 'param_coef0': 573}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:18,930] Trial 51 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0016876071402896018, 'param_degree': 2, 'param_coef0': 411}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,084] Trial 52 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0021133176371447436, 'param_degree': 2, 'param_coef0': 345}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,217] Trial 53 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.001417589046447904, 'param_degree': 2, 'param_coef0': 220}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,372] Trial 54 finished with value: 0.9583574879227053 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.3793686263019769, 'param_degree': 2, 'param_coef0': 368}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,545] Trial 55 finished with value: 0.9692270531400966 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.010946481914589398, 'param_degree': 2, 'param_coef0': 297}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,692] Trial 56 finished with value: 0.9801932367149758 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0018184869854824964, 'param_degree': 2, 'param_coef0': 480}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,844] Trial 57 finished with value: 0.9670531400966184 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.005619005990369182, 'param_degree': 2, 'param_coef0': 473}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:19,980] Trial 58 finished with value: 0.9714975845410627 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.045957904406277075}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,083] Trial 59 finished with value: 0.9584057971014494 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 124.58752469045658, 'param_degree': 3, 'param_coef0': 427}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,175] Trial 60 finished with value: 0.9670531400966184 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0046799962795218445, 'param_degree': 2, 'param_coef0': 528}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,248] Trial 61 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0019601858922646217, 'param_degree': 2, 'param_coef0': 349}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,390] Trial 62 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.001733042298114095, 'param_degree': 2, 'param_coef0': 272}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,518] Trial 63 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0018827153914587722, 'param_degree': 2, 'param_coef0': 421}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,654] Trial 64 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010076203759181923, 'param_degree': 2, 'param_coef0': 474}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,796] Trial 65 finished with value: 0.9583091787439614 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.008158200260488802, 'param_degree': 1, 'param_coef0': 594}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:20,935] Trial 66 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0018428235983257574, 'param_degree': 2, 'param_coef0': 523}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:21,081] Trial 67 finished with value: 0.96487922705314 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 2.3259122625063937, 'param_degree': 2, 'param_coef0': 399}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:21,404] Trial 68 finished with value: 0.6263285024154589 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 975.5899161074905}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:21,559] Trial 69 finished with value: 0.9692270531400966 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.004617132954155073, 'param_degree': 2, 'param_coef0': 647}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:21,787] Trial 70 finished with value: 0.956135265700483 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.013998996693333906, 'param_degree': 3, 'param_coef0': 163}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:21,925] Trial 71 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.001964184972908452, 'param_degree': 2, 'param_coef0': 340}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:22,056] Trial 72 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0015612623944369142, 'param_degree': 2, 'param_coef0': 253}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:22,247] Trial 73 finished with value: 0.9692753623188406 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.003863972604473463, 'param_degree': 2, 'param_coef0': 352}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:22,387] Trial 74 finished with value: 0.9692753623188406 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002186404275183447, 'param_degree': 2, 'param_coef0': 575}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:22,530] Trial 75 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0014008903399021445, 'param_degree': 2, 'param_coef0': 460}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:22,935] Trial 76 finished with value: 0.9692270531400966 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0071261498467951705, 'param_degree': 2, 'param_coef0': 493}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:23,062] Trial 77 finished with value: 0.9692753623188406 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.003140530148328793, 'param_degree': 2, 'param_coef0': 397}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:23,161] Trial 78 finished with value: 0.9385024154589372 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010220488022125915, 'param_degree': 1, 'param_coef0': 541}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:23,355] Trial 79 finished with value: 0.9605314009661836 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.04391269800420434, 'param_degree': 2, 'param_coef0': 299}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:23,693] Trial 80 finished with value: 0.6263285024154589 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 3.9448424311869945}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:23,792] Trial 81 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0021924811897823587, 'param_degree': 2, 'param_coef0': 431}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:23,864] Trial 82 finished with value: 0.9736714975845411 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0015220047889018494, 'param_degree': 2, 'param_coef0': 394}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:24,034] Trial 83 finished with value: 0.973719806763285 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0025655427702835324, 'param_degree': 2, 'param_coef0': 625}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:24,229] Trial 84 finished with value: 0.9714492753623188 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.00381020290927766, 'param_degree': 2, 'param_coef0': 444}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:24,477] Trial 85 finished with value: 0.9670531400966184 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.008346803050993914, 'param_degree': 2, 'param_coef0': 341}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:24,698] Trial 86 finished with value: 0.9692270531400966 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.005131697646402436, 'param_degree': 2, 'param_coef0': 584}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:24,942] Trial 87 finished with value: 0.9801932367149758 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0016329922223740638, 'param_degree': 2, 'param_coef0': 502}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:25,158] Trial 88 finished with value: 0.9605314009661836 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.020115158202547282, 'param_degree': 2, 'param_coef0': 498}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:25,293] Trial 89 finished with value: 0.964975845410628 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 14.151171588499393, 'param_degree': 3, 'param_coef0': 550}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:25,440] Trial 90 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0012807291777734292, 'param_degree': 2, 'param_coef0': 477}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:25,643] Trial 91 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002215978836539432, 'param_degree': 2, 'param_coef0': 418}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:25,775] Trial 92 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.00292093646979285, 'param_degree': 2, 'param_coef0': 367}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:25,929] Trial 93 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0014880437008746997, 'param_degree': 2, 'param_coef0': 517}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:26,120] Trial 94 finished with value: 0.971400966183575 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.004063676403117294, 'param_degree': 2, 'param_coef0': 609}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:26,393] Trial 95 finished with value: 0.9758454106280194 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.001347957923514213, 'param_degree': 2, 'param_coef0': 454}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:26,724] Trial 96 finished with value: 0.9714492753623188 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.002117294121548855, 'param_degree': 2, 'param_coef0': 552}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_rbf = trial.suggest_loguniform('param_gamma_rbf', 1e-3, 1e3)
# [I 2024-10-28 07:27:26,828] Trial 97 finished with value: 0.9736714975845411 and parameters: {'param_kernel': 'rbf', 'param_gamma_rbf': 0.02300907523296629}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:26,961] Trial 98 finished with value: 0.9780193236714976 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0032508130967609018, 'param_degree': 2, 'param_coef0': 316}. Best is trial 21 with value: 0.9801932367149758.
# <ipython-input-9-a00617d4470c>:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   param_gamma_poly = trial.suggest_loguniform('param_gamma_poly', 1e-3, 1e3)
# [I 2024-10-28 07:27:27,201] Trial 99 finished with value: 0.9736714975845411 and parameters: {'param_kernel': 'poly', 'param_gamma_poly': 0.0010180562995439526, 'param_degree': 2, 'param_coef0': 657}. Best is trial 21 with value: 0.9801932367149758.

# %%
# 最適化されたパラメータでSVMを学習
if study_new.best_params['param_kernel'] == 'rbf':
    svm_best = SVC(kernel='rbf', gamma=study_new.best_params['param_gamma_rbf'])
else:
    svm_best = SVC(kernel='poly', gamma=study_new.best_params['param_gamma_poly'],
                  degree=study_new.best_params['param_degree'], coef0=study_new.best_params['param_coef0'])

svm_best.fit(X_train, y_train)

# 学習データとテストデータに対するAccuracyを算出
trn_acc = svm_best.score(X_train, y_train)
tst_acc = svm_best.score(X_test, y_test)

print('Training data: %1.3f' % trn_acc)
print('Test data: %1.3f' % tst_acc)
print('Best params:')
print(study_new.best_params)
# Out:
# Training data: 0.991
# Test data: 0.965
# Best params:
# {'param_kernel': 'poly', 'param_gamma_poly': 0.001539779480434535, 'param_degree': 2, 'param_coef0': 560}
